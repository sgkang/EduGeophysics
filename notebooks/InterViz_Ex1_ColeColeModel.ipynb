# %%
from IPython.html.widgets import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys

# %%
#You should add your path where EduGeophysics is located
sys.path.append("C:\Users\SEOGI\projects\EduGeophysics")

# %% [markdown]
# Or you can type on your terminal:
#
# $git clone https://github.com/sgkang/EduGeophysics.git

# %%
from EduGeo import ColeCole

# %%
i = interact(ColeCole.ColeColeFplot, siginf = (-3, 0, 1), eta = (0.1, 0.9, 0.1), \
         tau =(-4, 0, 0.5), c = (0.1, 1, 0.1), fmin = (-5, -0, 1), fmax = (3, 8, 1) )

# %%
i.widget
