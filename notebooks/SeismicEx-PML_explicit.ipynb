# %%
from SimPEG import *
import scipy
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cs = 0.5
hx = np.ones(250)*cs
hy = np.ones(250)*cs
mesh = Mesh.TensorMesh([hx, hy], 'CC')

# %% [markdown]
# ## Acoustic Wave equation in time domain (1st order form)

# %% [markdown]
# $ \rho\frac{\partial p}{\partial t} = \nabla \cdot \vec{u}+\frac{\partial s}{\partial t}\delta(\vec{r}-\vec{r}_s)$
#
# $ \mu^{-1}\frac{\partial \vec{u}}{\partial t} = \nabla p$

# %% [markdown]
# ## Add damping term

# %% [markdown]
# $ \rho[\frac{\partial p}{\partial t} + \sigma p] = \nabla \cdot \vec{u}+\frac{\partial s}{\partial t}\delta(\vec{r}-\vec{r}_s)$
#
# $ \mu^{-1}[\frac{\partial \vec{u}}{\partial t}] = \nabla p$

# %% [markdown]
# ## Discretized form

# %% [markdown]
# $ \mathbf{diag}(\rho)\frac{\mathbf{p}^{n+1}-\mathbf{p}^{n}}{\triangle t} +  \mathbf{diag}(\rho\sigma)\mathbf{p}^n = \mathbf{Div} \mathbf{u}^{n+1/2}+\mathbf{M}^{cc -1}\frac{\mathbf{s}^{n+1}-\mathbf{s}^{n}}{\triangle t}$
#
#
# $ \mathbf{diag}(\mathbf{Av}^{f}_{cc}\mu^{-1})\frac{\mathbf{u}^{n+1/2}-\mathbf{u}^{n-1/2}}{\triangle t} +=  \mathbf{Grad} \mathbf{p}^{n}$

# %% [markdown]
# ## Compute p first

# %% [markdown]
# $ \mathbf{p}^{n+1} = \mathbf{p}^{n} - \triangle t\mathbf{diag}(\sigma)\mathbf{p}^n + \mathbf{diag}(\rho)^{-1}\triangle t[\mathbf{Div} \mathbf{u}^{n+1/2}+\mathbf{M}^{cc -1}\frac{\mathbf{s}^{n+1}-\mathbf{s}^{n}}{\triangle t}]$

# %% [markdown]
# ## Then compute u

# %% [markdown]
# $ \mathbf{u}^{n+1/2} = \mathbf{u}^{n-1/2} - \triangle t\mathbf{diag}(\sigma)\mathbf{u}^{n-1/2}+\triangle t\mathbf{diag}(\mathbf{Av}^{f}_{cc}\mu^{-1})^{-1}\mathbf{Grad} \mathbf{p}^{n}$

# %%
mesh.setCellGradBC('dirichlet')
Grad = mesh.cellGrad
Div = mesh.faceDiv
rho = np.ones(mesh.nC)*2700
vhalf = 2000
vblk = 2000
v = np.ones(mesh.nC)*vhalf
blkind = np.logical_and(mesh.gridCC[:,1]>-12.5, mesh.gridCC[:,1]<12.5) & np.logical_and(mesh.gridCC[:,0]>-12.5, mesh.gridCC[:,0]<12.5)
v[blkind] = vblk
mu = rho*v**2
AvF2CC = mesh.aveF2CC

# %%
time = np.linspace(0, 0.08, 2**10)
dt = time[1]-time[0]

# %%
print dt
# Out:
# 7.82013685239e-05

# %%
ax = mesh.vectorCCx[-20]
ay = mesh.vectorCCy[-20]
indy = np.logical_or(mesh.gridCC[:,1]<=-ay, mesh.gridCC[:,1]>=ay)
indx = np.logical_or(mesh.gridCC[:,0]<=-ax, mesh.gridCC[:,0]>=ax)

sigx = zeros_like(mesh.gridCC[:,0])
sigx[indx] = (abs(mesh.gridCC[:,0][indx])-ax)**2
sigx[indx] = sigx[indx]-sigx[indx].min()
sigx[indx] = sigx[indx]/sigx[indx].max()

# %%
sigy = zeros_like(mesh.gridCC[:,1])
sigy[indy] = (abs(mesh.gridCC[:,1][indy])-ay)**2
sigy[indy] = sigy[indy]-sigy[indy].min()
sigy[indy] = sigy[indy]/sigy[indy].max()

# %%
L = (mesh.hx.sum()-ax)*0.5
sigmax = L*100

# %%
print sigmax
# Out:
# 3612.5

# %%
sig = (sigx+sigy)*sigmax
sig[indy & indx] = sig[indy & indx]*0.5

# %%
sig.max()
# Out:
# 3612.5

# %%
dat = mesh.plotImage(v)
plt.colorbar(dat[0])
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/colorbar.py:829: RuntimeWarning: invalid value encountered in divide
#   z = np.take(y, i0) + (xn - np.take(b, i0)) * dy / db
# /usr/local/lib/python2.7/dist-packages/matplotlib/colorbar.py:581: RuntimeWarning: invalid value encountered in greater
#   inrange = (ticks > -0.001) & (ticks < 1.001)
# /usr/local/lib/python2.7/dist-packages/matplotlib/colorbar.py:581: RuntimeWarning: invalid value encountered in less
#   inrange = (ticks > -0.001) & (ticks < 1.001)
# <matplotlib.colorbar.Colorbar instance at 0x8b4cb90>

# %%
plt.plot(mesh.vectorCCx, sig[mesh.gridCC[:,1]==mesh.vectorCCy[125]], '.')

# %%
sigy = zeros_like(mesh.gridCC[:,1])
sigy[mesh.gridCC[:,1]<-ay] = (mesh.gridCC[:,1][mesh.gridCC[:,1]<-ay]-ay)**2
refy = sigy[mesh.gridCC[:,0]<-ay].max()
sigy[mesh.gridCC[:,1]>ay] = (mesh.gridCC[:,1][mesh.gridCC[:,1]>ay]+ay)**2
sigy = sigy/refy

# %%
def ricker(fpeak, t, tlag):
    """
        Generating Ricker Wavelet
        
        .. math ::
        
        
    """
    return (1-2*np.pi**2*fpeak**2*(t-tlag)**2)*np.exp(-np.pi**2*fpeak**2*(t-tlag)**2)

# %%
wave = ricker(400, time, 0.0025)

# %%
fig, ax = plt.subplots(1,1, figsize = (7, 5))
ax.plot(time, wave, '.-')
ax.set_xlim(0, 0.02)
# Out:
# (0, 0.02)

# %%
txind = Utils.closestPoints(mesh, [0., 30.], gridLoc='CC')
q = Utils.sdiag(1/mesh.vol)*np.zeros(mesh.nC)
q[txind] = 1.

# %%
p = np.zeros((mesh.nC, time.size))
pn = np.zeros(mesh.nC)
p0 = np.zeros_like(pn)
un = np.zeros(mesh.nF)
u0 = np.zeros_like(un)

# %%
Proj = mesh.getInterpolationMat(np.r_[3., 30], 'CC')

# %%
# %%time
for i in range(time.size-1):
    sn = ricker(400, time[i+1], 0.0025)
    s0 = ricker(400, time[i], 0.0025)
    pn = p0-dt*Utils.sdiag(sig)*p0+Utils.sdiag(1/rho)*dt*(Div*un+(sn-s0)/dt*q)
    p0 = pn.copy()
    un = u0 - dt*Utils.sdiag(AvF2CC.T*sig)*u0 + dt*Utils.sdiag(1/(AvF2CC.T*(1/mu)))*Grad*p0
    u0 = un.copy()
    p[:,i+1] = pn
# Out:
# CPU times: user 19.9 s, sys: 89.5 ms, total: 20 s
# Wall time: 20 s

# %%
data = Proj*p

# %%
import JSAnimation

# %%
import urllib

# %%
extent = [mesh.vectorCCx.min(), mesh.vectorCCx.max(), mesh.vectorCCy.min(), mesh.vectorCCy.max()]
extent[:2]
# Out:
# [-62.25, 62.25]

# %%
from JSAnimation import IPython_display
from matplotlib import animation
fig, ax = subplots(1,2, figsize = (16, 8))
ax[0].set_xlabel('Easting (m)')
ax[0].set_ylabel('Depth (m)')
extent = [mesh.vectorCCx.min(), mesh.vectorCCx.max(), mesh.vectorCCy.min(), mesh.vectorCCy.max()]
ax[0].set_xlim(extent[:2])
ax[0].set_ylim(extent[2:])
ax[1].plot(Utils.mkvc(data), time, 'k--',)
ax[1].set_xlim(data.min(), data.max())
ax[1].set_ylim(time.min(), 0.04)
ax[1].invert_yaxis()

line, = ax[1].plot([], [], color="black", lw=2)
nskip = 10
def animate(i_id):
    icount = i_id*nskip
    frame = ax[0].imshow(np.flipud(p[:,icount].reshape((250, 250), order = 'F').T), cmap = 'binary', extent=extent)
    
    tx = ax[0].plot(mesh.gridCC[txind,0], mesh.gridCC[txind,1], 'k.', ms = 10)
    rx = ax[0].plot(10, 30, 'r.', ms = 10)
    text_tx = ax[0].text(mesh.gridCC[txind,0]-15., mesh.gridCC[txind,1], 'Tx', fontsize = 18)
    text_tx = ax[0].text(10+5., 30, 'Rx', fontsize = 18, color="red")
    ax[0].plot(np.r_[-12.5, 12.5, 12.5, -12.5, -12.5], np.r_[-12.5, -12.5, 12.5, 12.5, -12.5], 'w-', lw=2)
    line.set_data([Utils.mkvc(data)[:icount]], [time[:icount]])
    return frame, line
animation.FuncAnimation(fig, animate, frames=40, interval=40, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgJTPZYYBZUPAFTHCS">
#     <br>
#     <input id="_anim_sliderJTPZYYBZUPAFTHCS" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animJTPZYYBZUPAFTHCS.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animJTPZYYBZUPAFTHCS.slower()">&#8211;</button>
#     <button onclick="animJTPZYYBZUPAFTHCS.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animJTPZYYBZUPAFTHCS.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animJTPZYYBZUPAFTHCS.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animJTPZYYBZUPAFTHCS.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animJTPZYYBZUPAFTHCS.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animJTPZYYBZUPAFTHCS.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animJTPZYYBZUPAFTHCS.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animJTPZYYBZUPAFTHCS.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectJTPZYYBZUPAFTHCS" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgJTPZYYBZUPAFTHCS";
#     var slider_id = "_anim_sliderJTPZYYBZUPAFTHCS";
#     var loop_select_id = "_anim_loop_selectJTPZYYBZUPAFTHCS";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAIABJREFUeJzs3Xl4VPXZ//HPycKWBAKBJGQpAUMScAGUwOVKUANIC9Ky\
# CK2aKigPfaggtiyuwV/VoNKIUi0oBWkfKTyoEDVGBQ2INCzKooIsKhICCWIIECCEzMzvjzyMxjOs\
# M5lDzrxf1zUXmeSemXu+ytzw4XvOMVwul0sAAAAAAACwrSCrGwAAAAAAAED9IgACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAAAAAAJsjAAIAAAAAALA5AiAAAAAAAACbIwACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAAAAAAJsjAAIAAAAAALA5AiAAAAAAAACbIwACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAAAAAAJsjAAIAAAAAALA5AiAAAAAAAACbIwACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAAAAAAJsjAAIAAAAAALA5AiAAAAAAAACbIwACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAAAAAAJsjAAIAAAAAALA5AiAAAAAAAACbIwACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAAAAAAJsjAAIAAAAAALA5AiAAAAAAAACbIwACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAAAAAAJsjAAIAAAAAALA5AiAAAAAAAACbIwACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAAAAAAJsjAAIAAAAAALA5AiAAAAAAAACbIwACAAAAAACwOQIg\
# AAAAAAAAmyMAAgAAAAAAsDkCIAAAgHpQUFCgtLQ0dezYUdOmTfNYc99996ljx47q0qWLNmzYcNbH\
# lpeXKzMzUykpKerTp48qKirq/X0AAAB7IAACAADwMYfDobFjx6qgoEBbtmzRggULtHXr1jo1+fn5\
# 2rlzp3bs2KHZs2drzJgxZ31sTk6OMjMztX37dt10003Kycnx+3sDAAANEwEQAACAj61du1bJyclK\
# SkpSaGiohg8frqVLl9apycvLU1ZWliSpZ8+eqqioUGlp6Rkf+9PHZGVlacmSJf59YwAAoMEiAAIA\
# APCxkpISJSYmuu8nJCSopKTknGr27t172seWlZUpJiZGkhQTE6OysrL6fBsAAMBGCIAAAAB8zDCM\
# c6pzuVznVOPp+QzDOOfXAQAACLG6AQAAALuJj49XcXGx+35xcbESEhLOWLNnzx4lJCTo5MmTpu/H\
# x8dLqt31U1paqtjYWO3bt0/R0dGm1+7atas2bdrk67cEAAhQXbp00caNG61uAz7ADiAAAAAf6969\
# u3bs2KFdu3apurpaCxcu1MCBA+vUDBw4UPPnz5ckFRUVKTIyUjExMWd87MCBA/Xqq69Kkl599VUN\
# GjTI9NqbNm2Sy+Uy3R577DGP3+fW8G78t2z4ty+//FKtW7e2vA9uvrnZ/fck/6hgH+wAAgAA8LGQ\
# kBDNnDlTffv2lcPh0MiRI9WpUyfNmjVLkjR69Gj1799f+fn5Sk5OVlhYmObOnXvGx0rS5MmTNWzY\
# MM2ZM0dJSUlatGiRZe8RwIVzOp1WtwAgABEAAQAA1INbbrlFt9xyS53vjR49us79mTNnnvNjJalV\
# q1ZatmyZ75oEYAmXy/O5vQCgPnEIGAAAQADIyMiwugX4CP8tGz6n06mIiAir24CP8HsSDYXhcrnO\
# fvkJAAAANAiGYYg/3gEXt+LiYs2bN0+PPPKI1a0AZ8VcsQ8CIAAAABvhD+oAAF9irtgHh4ABAAAA\
# AADYHAEQAAAAAACAzREAAQAAAAAA2BwBEAAAAAAAgM0RAAEAAACAH73wwgvav3+/1W0ACDAEQAAA\
# AADgJ0uXLlVubq6aN29udSsAAkyI1Q0AAAAAQCDIy8vTqFGj9Pbbb6tJkyZWtwMgwBAAAQAAAEA9\
# OnDggB588EG9++67euedd9SjRw+rWwIQgAiAAAAAAKAezZkzR02aNNEXX3yhFi1aWN0OgABluFwu\
# l9VNAAAAwDcMwxB/vAMA+ApzxT7YAQQAAAAAF+jw4cNavXq1VqxYoc8//1xvvfWWDMOwui0AMOEq\
# YAAAAABwHlwul8aNG6f09HTFxcUpJydHoaGhmjJlitWtAcBpsQMIAAAAAH7m5MmT2rJli1JSUtS0\
# adM6PzMMQ126dNHQoUOVnp6uxo0bW9QlAJw7zgEEr2RkZGjFihVWtwEAsIlevXqpsLDQ6jYaNM7V\
# AFyYbdu26T//+Y/Wr1+v9evX6/PPP9cvfvELvfnmm0pLS7O6PcAyzBX74BAweGXFihVyuVweb489\
# 9thpfxZIN9aBNWANWAPW4NzXgH9UAGCVv//971q2bJkuueQSPf300yotLdXWrVsJfwDYBoeAQZJU\
# UVGhUaNG6csvv5RhGJo7d646duyo2267Td99952SkpK0aNEiRUZGWt0qAAAAcN727t2rF198UVde\
# eaV+85vfmH6em5
